# %% [markdown]
# # **Data Preprocessing**

# %%
import os
import pandas as pd
import numpy as np
import gc
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import initializers
from tensorflow import keras
from scipy import stats
from tensorflow.python.ops import math_ops
from tensorflow.python.keras import backend as K

from google.colab import drive
drive.mount('/content/drive')

tf.random.set_seed(3)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Transformer**

# %%
class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = keras.Sequential(
            [layers.Dense(ff_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

# %%
def get_model_transformer():
  embed_dim = 300  # Embedding size for each token
  num_heads = 8  # Number of attention heads
  ff_dim = 512  # Hidden layer size in feed forward network inside transformer

  transformer_block = TransformerBlock(embed_dim, num_heads, ff_dim)
  features_input = tf.keras.Input((300,), dtype=tf.float16)
  features_inputs = layers.Reshape((1,300))(features_input)

# 6 transformer blocks
  features_x = transformer_block(features_inputs)
  features_x = transformer_block(features_x)
  features_x = transformer_block(features_x)
  features_x = transformer_block(features_x)
  features_x = transformer_block(features_x)
  features_x = transformer_block(features_x)

  features_x = layers.Reshape((300,))(features_x)
# MLP for output
  output_x = layers.Dense(512, activation='swish',
                          kernel_initializer=initializers.RandomNormal(stddev=1))(features_x)
  output_x = layers.Dropout(0.6)(output_x)
  output_x = layers.Dense(256, activation='swish',
                          kernel_initializer=initializers.RandomNormal(stddev=1))(output_x)
  output_x = layers.Dropout(0.6)(output_x)
  output_x = layers.Dense(128, activation='swish',
                          kernel_initializer=initializers.RandomNormal(stddev=1))(output_x)
  output_x = layers.Dense(64, activation='swish',
                          kernel_initializer=initializers.RandomNormal(stddev=1),
                          kernel_regularizer="l2")(output_x)
  output_x = layers.Dropout(0.6)(output_x)
  output_x = layers.Dense(32, activation='swish',
                          kernel_initializer=initializers.RandomNormal(stddev=1),
                          kernel_regularizer="l2")(output_x)
  output_x = layers.Dropout(0.6)(output_x)
  output_x = layers.Dense(16, activation='swish',
                          kernel_initializer=initializers.RandomNormal(stddev=1),
                          kernel_regularizer="l2")(output_x)
  output_x = layers.Dropout(0.6)(output_x)
  output = layers.Dense(1)(output_x)
  output = tf.keras.layers.BatchNormalization(axis=1)(output)

# Model compilation
  rmse = keras.metrics.RootMeanSquaredError(name="rmse")
  model = tf.keras.Model(inputs=[features_input], outputs=[output])
  # learning rate decay in Adam
  initial_learning_rate = 3e-5
  lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate,
        decay_steps=10000,
        decay_rate=0.9,
        staircase=True)
  model.compile(optimizer=tf.optimizers.Adam(learning_rate=lr_schedule), 
                loss='mse', 
                metrics=['mse', "mae", "mape", rmse])
  return model

# %%
model = get_model_transformer()
model.summary()
# keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 300)]        0           []
#
#  reshape (Reshape)              (None, 1, 300)       0           ['input_1[0][0]']
#
#  transformer_block (Transformer  (None, 1, 300)      3196712     ['reshape[0][0]',
#  Block)                                                           'transformer_block[0][0]',
#                                                                   'transformer_block[1][0]',
#                                                                   'transformer_block[2][0]',
#                                                                   'transformer_block[3][0]',
#                                                                   'transformer_block[4][0]']
#
#  reshape_1 (Reshape)            (None, 300)          0           ['transformer_block[5][0]']
#
#  dense_2 (Dense)                (None, 512)          154112      ['reshape_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 512)          0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 256)          131328      ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 256)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 128)          32896       ['dropout_3[0][0]']
#
#  dense_5 (Dense)                (None, 64)           8256        ['dense_4[0][0]']
#
#  dropout_4 (Dropout)            (None, 64)           0           ['dense_5[0][0]']
#
#  dense_6 (Dense)                (None, 32)           2080        ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 32)           0           ['dense_6[0][0]']
#
#  dense_7 (Dense)                (None, 16)           528         ['dropout_5[0][0]']
#
#  dropout_6 (Dropout)            (None, 16)           0           ['dense_7[0][0]']
#
#  dense_8 (Dense)                (None, 1)            17          ['dropout_6[0][0]']
#
#  batch_normalization (BatchNorm  (None, 1)           4           ['dense_8[0][0]']
#  alization)
#
# ==================================================================================================
# Total params: 3,525,933
# Trainable params: 3,525,931
# Non-trainable params: 2
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model, show_shapes=True)

# %%
model_pretrained = get_model_transformer()
model_pretrained.load_weights("/content/model_1.tf")

# %%
def make_test_dataset2(feature, batch_size=1024):
    ds = tf.data.Dataset.from_tensor_slices(feature)
    ds = ds.batch(batch_size).cache().prefetch(tf.data.AUTOTUNE)
    return ds

# %%
test_ds = make_test_dataset2(val_data[features])

# %%
y_pred = model_pretrained.predict(test_ds)

# %%
y_pred.reshape(-1)
# Out:
# array([ 0.02273047, -0.011073  , -0.02909887, ...,  0.01755066,
#         0.00625037, -0.11245453], dtype=float32)

# %%
checkpoint = keras.callbacks.ModelCheckpoint(f"model_1.tf", monitor="val_loss", mode="min", save_best_only=True, save_weights_only=True)
early_stop = keras.callbacks.EarlyStopping(patience=10)
history = model.fit(train_ds, epochs=30, validation_data=val_ds, shuffle=False, callbacks=[checkpoint, early_stop])
model.save_weights(f"model_1.tf")
# Out:
# Epoch 1/30
# 2377/2377 [==============================] - 170s 68ms/step - loss: 103.3719 - mse: 1.7685 - mae: 0.9521 - mape: 342300.1250 - rmse: 1.3299 - val_loss: 96.8174 - val_mse: 0.8587 - val_mae: 0.6241 - val_mape: 95543.0391 - val_rmse: 0.9266
# Epoch 2/30
# 2377/2377 [==============================] - 161s 68ms/step - loss: 92.3102 - mse: 1.6170 - mae: 0.8855 - mape: 271054.5938 - rmse: 1.2716 - val_loss: 86.4561 - val_mse: 0.8714 - val_mae: 0.6378 - val_mape: 98255.6328 - val_rmse: 0.9335
# Epoch 3/30
# 2377/2377 [==============================] - 161s 68ms/step - loss:
# Epoch 29/30
# 2377/2377 [==============================] - 160s 67ms/step - loss: 12.5089 - mse: 0.8464 - mae: 0.6344 - mape: 41435.7812 - rmse: 0.9200 - val_loss: 12.2326 - val_mse: 0.8183 - val_mae: 0.6011 - val_mape: 17711.7324 - val_rmse: 0.9046
# Epoch 30/30
# 2377/2377 [==============================] - 161s 68ms/step - loss: 12.0331 - mse: 0.8460 - mae: 0.6343 - mape: 40760.8359 - rmse: 0.9198 - val_loss: 11.8042 - val_mse: 0.8184 - val_mae: 0.6011 - val_mape: 18099.8789 - val_rmse: 0.9046

# %%
for metric in ["loss", "mae", "mape", "rmse"]:
  pd.DataFrame(history.history, columns=[metric, f"val_{metric}"]).plot()
  plt.title(metric.upper())
  plt.show()

# %% [markdown]
# ### Using random mask trick

# %%
from sklearn.model_selection import StratifiedKFold

# %%
def gen_ids_and_skf_idxs():
    train = pd.read_parquet("/content/drive/MyDrive/CSC413/Final Project/data/train_low_mem.parquet")
    investment_id = train[["investment_id"]].astype('int64')
    train.pop("investment_id")
    train.pop("time_id")
    train.pop("target")
    skf = StratifiedKFold(5, shuffle=True, random_state=42)
    idxs = list(enumerate(skf.split(train, investment_id)))
    del train
    gc.collect()
    return investment_id, idxs

# %%
investment_id, idxs = gen_ids_and_skf_idxs()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:680: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   UserWarning,

# %%
def correlation(x, y, axis=-2):
    xmean = tf.reduce_mean(x, axis=axis)
    ymean = tf.reduce_mean(y, axis=axis)
    cossim = keras.losses.cosine_similarity(x - xmean, y - ymean, axis=axis)
    return 1 + cossim

# %%
# Random mask:
# To force the inv_embedding layer to see the OOV id (0 in this case) in train data, which may help model to learn some "common knowledge" of the investment_id.
# And then when the model faces OOV investment_ids, the embedding of those ids would not be too random.

def random_mask(feas, target, ratio=0.1):
    inv_id, fea = feas
    mask = tf.random.uniform(tf.shape(inv_id)) < ratio
    inv_id = tf.where(mask, tf.constant(-1, dtype=tf.int64), inv_id)
    return (inv_id, fea), target

# %%
def make_dataset(feature, investment_id, y, batch_size=512, mode="train"):
    ds = tf.data.Dataset.from_tensor_slices(((investment_id, feature), y))
    if mode == "train":
        ds = ds.map(random_mask).shuffle(batch_size * 4)
    ds = ds.batch(batch_size).cache().prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
def get_tf_dataset(train_idx, test_idx):
    n_features = 300
    features = [f'f_{i}' for i in range(n_features)]
    df = pd.read_parquet("/content/drive/MyDrive/CSC413/Final Project/data/train_low_mem.parquet")
    con_feas = df[features]
    y = df['target']
    train_dataset = make_dataset(con_feas.iloc[train_idx, :], investment_id.iloc[train_idx], y.iloc[train_idx])
    val_dataset = make_dataset(con_feas.iloc[test_idx, :], investment_id.iloc[test_idx], y.iloc[test_idx], mode="valid")
    
    del df, con_feas, y
    gc.collect()
    
    return train_dataset, val_dataset

# %% [markdown]
# Scheduler which can be used for lr decay, weight decay, temperature decay, etc..

# %%
class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = keras.Sequential(
            [layers.Dense(ff_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

# %%
investment_ids = list(np.unique(investment_id.values))
investment_id_size = len(investment_ids) + 1
id_lookup_layer = layers.IntegerLookup(max_tokens=investment_id_size)
id_lookup_layer.adapt(investment_id)

# %%
def get_model_transformer():
  embed_dim = 300  # Embedding size for each token
  num_heads = 8  # Number of attention heads
  ff_dim = 512  # Hidden layer size in feed forward network inside transformer

  transformer_block = TransformerBlock(embed_dim, num_heads, ff_dim)
  features_input = tf.keras.Input((300,), dtype=tf.float32)
  investment_id_input = tf.keras.Input((1,))

  investment_id_x = id_lookup_layer(investment_id_input)
  investment_id_x = layers.Embedding(investment_id_size, 32)(investment_id_x)
  investment_id_x = layers.Dense(64, activation='swish', kernel_initializer='he_normal', bias_initializer='zeros')(investment_id_x)
  investment_id_x = layers.Dropout(0.5)(investment_id_x)
  investment_id_x = layers.Dense(32, activation='swish', kernel_initializer='he_normal', bias_initializer='zeros')(investment_id_x)
  investment_id_x = layers.Dropout(0.5)(investment_id_x)
  investment_id_x = tf.squeeze(investment_id_x, axis=1)

  features_inputs = tf.expand_dims(investment_id_x, axis = -1) + tf.expand_dims(features_input, axis = 1)
  # (None, 32, 300)

# 6 transformer blocks
  features_x = transformer_block(features_inputs)

  features_x = layers.Reshape((-1,))(features_x)
# MLP for output
  output_x = layers.Dense(512, activation='swish',
                          kernel_initializer=initializers.RandomNormal(stddev=1))(features_x)
  output_x = layers.Dropout(0.6)(output_x)
  output_x = layers.Dense(256, activation='swish',
                          kernel_initializer=initializers.RandomNormal(stddev=1))(output_x)
  output_x = layers.Dropout(0.6)(output_x)
  output_x = layers.Dense(128, activation='swish',
                          kernel_initializer=initializers.RandomNormal(stddev=1))(output_x)
  output_x = layers.Dense(64, activation='swish',
                          kernel_initializer=initializers.RandomNormal(stddev=1),
                          kernel_regularizer="l2")(output_x)
  output_x = layers.Dropout(0.6)(output_x)
  output_x = layers.Dense(32, activation='swish',
                          kernel_initializer=initializers.RandomNormal(stddev=1),
                          kernel_regularizer="l2")(output_x)
  output_x = layers.Dropout(0.6)(output_x)
  output_x = layers.Dense(16, activation='swish',
                          kernel_initializer=initializers.RandomNormal(stddev=1),
                          kernel_regularizer="l2")(output_x)
  output_x = layers.Dropout(0.6)(output_x)
  output = layers.Dense(1)(output_x)
  output = tf.keras.layers.BatchNormalization(axis=1)(output)

# Model compilation
  rmse = keras.metrics.RootMeanSquaredError(name="rmse")
  model = tf.keras.Model(inputs=[investment_id_input, features_input], outputs=[output])
  # learning rate decay in Adam
  initial_learning_rate = 5e-4
  lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate,
        decay_steps=10000,
        decay_rate=0.9,
        staircase=True)
  model.compile(optimizer=tf.optimizers.Adam(learning_rate=lr_schedule), 
                loss='mse', 
                metrics=[rmse, correlation])
  return model

# %%
model = get_model_transformer()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  integer_lookup (IntegerLookup)  (None, 1)           0           ['input_2[0][0]']
#
#  embedding (Embedding)          (None, 1, 32)        114560      ['integer_lookup[0][0]']
#
#  dense_2 (Dense)                (None, 1, 64)        2112        ['embedding[0][0]']
#
#  dropout_2 (Dropout)            (None, 1, 64)        0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 1, 32)        2080        ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 1, 32)        0           ['dense_3[0][0]']
#
#  tf.compat.v1.squeeze (TFOpLamb  (None, 32)          0           ['dropout_3[0][0]']
#  da)
#
#  input_1 (InputLayer)           [(None, 300)]        0           []
#
#  tf.expand_dims (TFOpLambda)    (None, 32, 1)        0           ['tf.compat.v1.squeeze[0][0]']
#
#  tf.expand_dims_1 (TFOpLambda)  (None, 1, 300)       0           ['input_1[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 32, 300)     0           ['tf.expand_dims[0][0]',
#  da)                                                              'tf.expand_dims_1[0][0]']
#
#  transformer_block (Transformer  (None, 32, 300)     3196712     ['tf.__operators__.add[0][0]']
#  Block)
#
#  reshape (Reshape)              (None, 9600)         0           ['transformer_block[0][0]']
#
#  dense_4 (Dense)                (None, 512)          4915712     ['reshape[0][0]']
#
#  dropout_4 (Dropout)            (None, 512)          0           ['dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 256)          131328      ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 256)          0           ['dense_5[0][0]']
#
#  dense_6 (Dense)                (None, 128)          32896       ['dropout_5[0][0]']
#
#  dense_7 (Dense)                (None, 64)           8256        ['dense_6[0][0]']
#
#  dropout_6 (Dropout)            (None, 64)           0           ['dense_7[0][0]']
#
#  dense_8 (Dense)                (None, 32)           2080        ['dropout_6[0][0]']
#
#  dropout_7 (Dropout)            (None, 32)           0           ['dense_8[0][0]']
#
#  dense_9 (Dense)                (None, 16)           528         ['dropout_7[0][0]']
#
#  dropout_8 (Dropout)            (None, 16)           0           ['dense_9[0][0]']
#
#  dense_10 (Dense)               (None, 1)            17          ['dropout_8[0][0]']
#
#  batch_normalization (BatchNorm  (None, 1)           4           ['dense_10[0][0]']
#  alization)
#
# ==================================================================================================
# Total params: 8,406,285
# Trainable params: 8,406,283
# Non-trainable params: 2
# __________________________________________________________________________________________________

# %%
# %%time
for idx, (train_idx, test_idx) in idxs:
    print(f"the {idx}th fold:")
    
    print("train_idx and test_idx:")
    print(train_idx, test_idx)
    
    print("get tf_dataset...")
    train_dataset, val_dataset = get_tf_dataset(train_idx, test_idx)

    print("get model...")
    model = get_model_transformer()

    checkpoint = keras.callbacks.ModelCheckpoint(f'model_{idx}.tf', monitor="val_correlation", save_best_only=True, save_weights_only=True)
    early_stop = keras.callbacks.EarlyStopping(monitor="val_correlation", patience=10, mode='min')
    
    print("start training...")
    history = model.fit(train_dataset, epochs=30, validation_data=val_dataset, callbacks=[checkpoint, early_stop])
    
    model.save_weights(f"model_{idx}.tf")
    for metric in ["rmse", "correlation"]:
        pd.DataFrame(history.history, columns=[metric, f"val_{metric}"]).plot()
        plt.title(metric.upper())
        plt.show()
    
    del train_dataset, val_dataset, model, checkpoint, early_stop, history
    gc.collect()
# Out:
# the 0th fold:
# train_idx and test_idx:
# [      0       1       2 ... 3141406 3141407 3141409] [      4       5      10 ... 3141399 3141404 3141408]
# get tf_dataset...
# get model...
# start training...
# Epoch 1/30
# 4909/4909 [==============================] - 274s 55ms/step - loss: 27.7700 - rmse: 0.9985 - correlation: 0.9631 - val_loss: 2.2714 - val_rmse: 0.9205 - val_correlation: 0.9204
# Epoch 2/30
# 4909/4909 [==============================] - 269s 55ms/step - loss: 1.0988 - rmse: 0.9170 - correlation: 0.9299 - val_loss: 0.8483 - val_rmse: 0.9193 - val_correlation: 0.9206
# Epoch 3/30
# 4909/4909 [==============================] - 271s 55ms/step - loss: 0.8414 - rmse: 0.9165 - correlation: 0.9225 - val_loss: 0.8452 - val_rmse: 0.9188 - val_correlation: 0.9121
# Epoch 4/30
# 4909/4909 [==============================] - 268s 55ms/step - loss: 0.8408 - rmse: 0.9162 - correlation: 0.9190 - val_loss: 0.8447 - val_rmse: 0.9185 - val_correlation: 0.9077
# Epoch 5/30
# 4909/4909 [==============================] - 268s 55ms/step - loss: 0.8400 - rmse: 0.9158 - correlation: 0.9136 - val_loss: 0.8442 - val_rmse: 0.9183 - val_correlation: 0.9091
# Epoch 6/30
# 4909/4909 [==============================] - 268s 55ms/step - loss: 0.8397 - rmse: 0.9157 - correlation: 0.9125 - val_loss: 0.8442 - val_rmse: 0.9183 - val_correlation: 0.9067
# Epoch 7/30
# 4909/4909 [==============================] - 269s 55ms/step - loss: 0.8394 - rmse: 0.9155 - correlation: 0.9102 - val_loss: 0.8446 - val_rmse: 0.9185 - val_correlation: 0.9010
# Epoch 8/30
# 4909/4909 [==============================] - 270s 55ms/step - loss: 0.8389 - rmse: 0.9152 - correlation: 0.9070 - val_loss: 0.8439 - val_rmse: 0.9182 - val_correlation: 0.8975
# Epoch 9/30
# 4909/4909 [==============================] - 267s 54ms/step - loss: 0.8386 - rmse: 0.9151 - correlation: 0.9053 - val_loss: 0.8439 - val_rmse: 0.9181 - val_correlation: 0.8982
# Epoch 10/30
# 4909/4909 [==============================] - 267s 54ms/step - loss: 0.8384 - rmse: 0.9150 - correlation: 0.9039 - val_loss: 0.8435 - val_rmse: 0.9180 - val_correlation: 0.9001
# Epoch 11/30
# 4909/4909 [==============================] - 266s 54ms/step - loss: 0.8382 - rmse: 0.9149 - correlation: 0.9032 - val_loss: 0.8440 - val_rmse: 0.9182 - val_correlation: 0.8996
# Epoch 12/30
# 4909/4909 [==============================] - 266s 54ms/step - loss: 0.8379 - rmse: 0.9148 - correlation: 0.9014 - val_loss: 0.8437 - val_rmse: 0.9181 - val_correlation: 0.8974
# Epoch 13/30
# 4909/4909 [==============================] - 268s 55ms/step - loss: 0.8375 - rmse: 0.9146 - correlation: 0.8996 - val_loss: 0.8433 - val_rmse: 0.9179 - val_correlation: 0.8964
# Epoch 14/30
# 4909/4909 [==============================] - 267s 54ms/step - loss: 0.8373 - rmse: 0.9145 - correlation: 0.8982 - val_loss: 0.8436 - val_rmse: 0.9180 - val_correlation: 0.9003
# Epoch 15/30
# 4909/4909 [==============================] - 266s 54ms/step - loss: 0.8370 - rmse: 0.9143 - correlation: 0.8967 - val_loss: 0.8438 - val_rmse: 0.9182 - val_correlation: 0.8995
# Epoch 16/30
# 4909/4909 [==============================] - 266s 54ms/step - loss: 0.8368 - rmse: 0.9142 - correlation: 0.8955 - val_loss: 0.8437 - val_rmse: 0.9181 - val_correlation: 0.8997
# Epoch 17/30
# 4909/4909 [==============================] - 266s 54ms/step - loss: 0.8365 - rmse: 0.9141 - correlation: 0.8941 - val_loss: 0.8437 - val_rmse: 0.9181 - val_correlation: 0.8986
# Epoch 18/30
# 4909/4909 [==============================] - 267s 54ms/step - loss: 0.8365 - rmse: 0.9140 - correlation: 0.8936 - val_loss: 0.8434 - val_rmse: 0.9180 - val_correlation: 0.8992
# Epoch 19/30
# 4909/4909 [==============================] - 270s 55ms/step - loss: 0.8362 - rmse: 0.9139 - correlation: 0.8925 - val_loss: 0.8432 - val_rmse: 0.9179 - val_correlation: 0.8978
# Epoch 20/30
# 4909/4909 [==============================] - 264s 54ms/step - loss: 0.8360 - rmse: 0.9138 - correlation: 0.8918 - val_loss: 0.8434 - val_rmse: 0.9180 - val_correlation: 0.8968
# Epoch 21/30
# 4909/4909 [==============================] - 262s 53ms/step - loss: 0.8359 - rmse: 0.9138 - correlation: 0.8912 - val_loss: 0.8445 - val_rmse: 0.9186 - val_correlation: 0.8940
# Epoch 22/30
# 4909/4909 [==============================] - 263s 53ms/step - loss: 0.8354 - rmse: 0.9135 - correlation: 0.8880 - val_loss: 0.8436 - val_rmse: 0.9180 - val_correlation: 0.8969
# Epoch 23/30
# 4909/4909 [==============================] - 262s 53ms/step - loss: 0.8347 - rmse: 0.9132 - correlation: 0.8846 - val_loss: 0.8423 - val_rmse: 0.9173 - val_correlation: 0.8963
# Epoch 24/30
# 4909/4909 [==============================] - 262s 53ms/step - loss: 0.8345 - rmse: 0.9130 - correlation: 0.8830 - val_loss: 0.8413 - val_rmse: 0.9167 - val_correlation: 0.8923
# Epoch 25/30
# 4909/4909 [==============================] - 265s 54ms/step - loss: 0.8341 - rmse: 0.9128 - correlation: 0.8814 - val_loss: 0.8426 - val_rmse: 0.9175 - val_correlation: 0.8966
# Epoch 26/30
# 4909/4909 [==============================] - 268s 55ms/step - loss: 0.8337 - rmse: 0.9127 - correlation: 0.8802 - val_loss: 0.8407 - val_rmse: 0.9165 - val_correlation: 0.8930
# Epoch 27/30
# 4909/4909 [==============================] - 265s 54ms/step - loss: 0.8336 - rmse: 0.9126 - correlation: 0.8792 - val_loss: 0.8401 - val_rmse: 0.9161 - val_correlation: 0.8901
# Epoch 28/30
# 4909/4909 [==============================] - 264s 54ms/step - loss: 0.8334 - rmse: 0.9125 - correlation: 0.8785 - val_loss: 0.8416 - val_rmse: 0.9170 - val_correlation: 0.8966
# Epoch 29/30
# 4909/4909 [==============================] - 266s 54ms/step - loss: 0.8332 - rmse: 0.9124 - correlation: 0.8778 - val_loss: 0.8387 - val_rmse: 0.9154 - val_correlation: 0.8829
# Epoch 30/30
# 4909/4909 [==============================] - 268s 55ms/step - loss: 0.8328 - rmse: 0.9122 - correlation: 0.8759 - val_loss: 0.8384 - val_rmse: 0.9152 - val_correlation: 0.8839
# the 1th fold:
# train_idx and test_idx:
# [      0       1       4 ... 3141407 3141408 3141409] [      2       3      18 ... 3141392 3141396 3141406]
# get tf_dataset...
# get model...
# start training...
# Epoch 1/30
# 4909/4909 [==============================] - 276s 56ms/step - loss: 27.8220 - rmse: 1.0000 - correlation: 0.9688 - val_loss: 2.4358 - val_rmse: 0.9185 - val_correlation: 0.9177
# Epoch 2/30
# 4909/4909 [==============================] - 270s 55ms/step - loss: 1.1346 - rmse: 0.9177 - correlation: 0.9332 - val_loss: 0.8462 - val_rmse: 0.9175 - val_correlation: 0.9222
# Epoch 3/30
# 4240/4909 [========================>.....] - ETA: 33s - loss: 0.8478 - rmse: 0.9198 - correlation: 0.9206
